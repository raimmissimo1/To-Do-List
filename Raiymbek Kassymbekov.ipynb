# %% [markdown]
#  **TO DO LIST**

# %%
print("----------------- Welcome to To Do List -----------------")

list_ = []
active = True

while active:
    print("1.See my To Do List")
    print("2.Add do things")
    print("3.Remove do things")
    print("4.Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        if not list_:
            print("List is empty")
        number = 1 
        for item in list_:
            print(f"{number} : {item}")
            number += 1
    elif choice == 2:
        add_do = input("Enter what you want to add: ")
        list_.append(add_do)
    elif choice == 3:
        remove_do = input("Enter what you want to remove")
        if remove  in list_:
            list_.remove(remove_do)
        else:
            print("There is not such a do thing:")
    
    elif choice == 4:
        active = False
        print("Thank you for using!!")

    else:
        print("Invalid choice!!")
# Out:
# ----------------- Welcome to To Do List -----------------
# 1.See my To Do List
# 2.Add do things
# 3.Remove do things
# 4.Exit
# Enter your choice:  2
# Enter what you want to add:  100 thins
# 1.See my To Do List
# 2.Add do things
# 3.Remove do things
# 4.Exit
# Enter your choice:  2
# Enter what you want to add:  200 things
# 1.See my To Do List
# 2.Add do things
# 3.Remove do things
# 4.Exit
# Enter your choice:  1
# 1 : 100 thins
# 2 : 200 things
# 1.See my To Do List
# 2.Add do things
# 3.Remove do things
# 4.Exit
# Enter your choice:  4
# Thank you for using!!
